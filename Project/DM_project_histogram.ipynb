# %% [markdown]
# ## Loading Data

# %%
import pandas as pd

# df = pd.DataFrame(pd.read_excel("Real estate valuation data set.xlsx"))
df = pd.read_excel("Real estate valuation data set.xlsx")

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ## Preporcessing

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Histogram

# %%
plt.title('Commute Times for 1,000 Commuters')
plt.xlabel('Counts')
plt.ylabel('Commute Time')

# %%
# X1 transaction date
# date是经过转换的时间
plt.hist(df['X1 transaction date'], edgecolor='k', alpha=0.35)
# plt.title()
plt.xlabel('Transaction date')
plt.ylabel('Counts')
plt.show()

# %%
# X2 house age
plt.hist(df['X2 house age'], edgecolor='k', alpha=0.35)
plt.xlabel('House age')
plt.ylabel('Counts')
plt.show()

# %%
# 横轴是meter，纵轴是数量

plt.hist(df['X3 distance to the nearest MRT station'], edgecolor='k', alpha=0.35)
plt.xlabel('Distance to the nearest MRT station')
plt.ylabel('Counts')
plt.show()

# %%
plt.hist(df['X4 number of convenience stores'], edgecolor='k', alpha=0.35)
plt.xlabel('Convenience stores')
plt.ylabel('Counts')
plt.show()

# %%
plt.hist(df['X5 latitude'], edgecolor='k', alpha=0.35)
plt.xlabel('Latitude')
plt.ylabel('Counts')
plt.show()

# %%
plt.hist(df['X6 longitude'], edgecolor='k', alpha=0.35)
plt.xlabel('Longitude')
plt.ylabel('Counts')
plt.show()

# %%
plt.hist(df['Y house price of unit area'], edgecolor='k', alpha=0.35)
plt.xlabel('House price of unit area')
plt.ylabel('Counts')
plt.show()

# %%
print(df['Y house price of unit area'].hist(edgecolor='k', alpha=0.35))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import numpy as np 
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
print(df['X2 house age'].describe())

stats.probplot(df['X2 house age'], dist="norm", plot=plt)
plt.show()
# Out:
# count    414.000000
# mean      17.712560
# std       11.392485
# min        0.000000
# 25%        9.025000
# 50%       16.100000
# 75%       28.150000
# max       43.800000
# Name: X2 house age, dtype: float64

# %%
print(df['X3 distance to the nearest MRT station'].describe())
stats.probplot(df['X3 distance to the nearest MRT station'], dist="norm", plot=plt)
plt.show()
# Out:
# count     414.000000
# mean     1083.885689
# std      1262.109595
# min        23.382840
# 25%       289.324800
# 50%       492.231300
# 75%      1454.279000
# max      6488.021000
# Name: X3 distance to the nearest MRT station, dtype: float64

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [0.99094823 0.00890494]
# [25649.82168739  2431.50090077]
